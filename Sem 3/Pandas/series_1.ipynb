# %% [markdown]
# import pandas as pd
# data = pd.Series([10,20,30,40])
# data

# %%
import pandas as pd
s = pd.Series([10,20,30], index = ['a','b','c'])
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=pd.Series([10,20,30],index = ['a','b','c'], dtype = "float")
s
# Out:
# a    10.0
# b    20.0
# c    30.0
# dtype: float64

# %%
s = pd.Series([10,20,30],index = ['a','b','c'], dtype = "float", name = "Python")
s
# Out:
# a    10.0
# b    20.0
# c    30.0
# Name: Python, dtype: float64

# %%
dic = {
    "Name": ["Python","C","C++","Java"],
    "Pos": [12,13,14,15],
    "Rank": [1,4,3,2]
    }
var1 = pd.Series(dic)
var1
# Out:
# Name    [Python, C, C++, Java]
# Pos           [12, 13, 14, 15]
# Rank              [1, 4, 3, 2]
# dtype: object

# %%
s = pd.Series(12)
s
# Out:
# 0    12
# dtype: int64

# %%
s = pd.Series(12, index = [1,2,3,4,5,6,7])
s
# Out:
# 1    12
# 2    12
# 3    12
# 4    12
# 5    12
# 6    12
# 7    12
# dtype: int64

# %%
s1 = pd.Series(12, index = [1,2,3,4,5,6,7])
s2 = pd.Series(12, index = [1,2,3,4,5])
print(s1+s2)
# Out:
# 1    24.0
# 2    24.0
# 3    24.0
# 4    24.0
# 5    24.0
# 6     NaN
# 7     NaN
# dtype: float64

# %%
import pandas as pd
prices = pd.Series([100,200,300])
print(prices[1])
# Out:
# 200

# %%
import pandas as pd
prices = pd.Series([100,200,300],index = ["Apple","Banana","Orange"])
print(prices["Apple"])
# Out:
# 100

# %%
import pandas as pd
ser = pd.Series()
ser
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
import numpy as np
ser = pd.Series(np.nan,index = range(100))
ser
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# Length: 100, dtype: float64

# %%
import pandas as pd
data_list  = ["g","e","k","s"]
ser = pd.Series(data_list)
ser
# Out:
# 0    g
# 1    e
# 2    k
# 3    s
# dtype: object

# %%
import numpy as np
data = np.array(["g","e","e","k","s"])
ser = pd.Series(data) 
ser
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
data
# Out:
# array(['g', 'e', 'e', 'k', 's'], dtype='<U1')

# %%
import pandas as pd
data_dict = {"Tic": 10, "Tac": 20, "Toe": 30}
ser = pd.Series(data_dict)
ser
# Out:
# Tic    10
# Tac    20
# Toe    30
# dtype: int64

# %%
ser = pd.Series(np.linspace(1,10,5))
ser
# Out:
# 0     1.00
# 1     3.25
# 2     5.50
# 3     7.75
# 4    10.00
# dtype: float64

# %%
ser = pd.Series(range(5,15))
ser
# Out:
# 0     5
# 1     6
# 2     7
# 3     8
# 4     9
# 5    10
# 6    11
# 7    12
# 8    13
# 9    14
# dtype: int64

# %%
ser = pd.Series(range(1,20,3) , index = [x for x in "abcdefg"])
ser
# Out:
# a     1
# b     4
# c     7
# d    10
# e    13
# f    16
# g    19
# dtype: int64
