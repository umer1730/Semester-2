# %%
import pandas as pd
data = pd.Series([10,20,30,40])
data
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
s = pd.Series([10,20,30], index = ['a','b','c'])
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64
